# %% [markdown]
# # All imports

# %%
pip install -U scikit-learn
# Out:
# ...
#      ---------------------------------------- 8.3/8.3 MB 3.6 MB/s eta 0:00:00
# ...
#      -------------------------------------- 298.0/298.0 kB 4.6 MB/s eta 0:00:00
# ...
#   Attempting uninstall: joblib
#     Found existing installation: joblib 1.1.0
#     Uninstalling joblib-1.1.0:
#       Successfully uninstalled joblib-1.1.0
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.0.2
#     Uninstalling scikit-learn-1.0.2:
#       Successfully uninstalled scikit-learn-1.0.2
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not install packages due to an OSError: [WinError 5] Access is denied: 'C:\\Users\\HP\\anaconda3\\Lib\\site-packages\\~klearn\\preprocessing\\_csr_polynomial_expansion.cp39-win_amd64.pyd'
# Consider using the `--user` option or check the permissions.

# %%
import pyforest

# %%
from matplotlib.colors import ListedColormap
import matplotlib.pyplot as plt
from dataprep.eda import plot, create_report
import scipy.stats as stat
from collections import Counter
import dataprep
from sklearn.svm import SVC
from imblearn.over_sampling import SMOTE,  ADASYN
from imblearn.combine import SMOTETomek, SMOTEENN
from sklearn.metrics import classification_report,confusion_matrix,accuracy_score
from statsmodels.stats.outliers_influence import variance_inflation_factor
from dataprep.eda import plot, plot_correlation, plot_missing, create_report
from sklearn.model_selection import KFold , GridSearchCV, train_test_split, StratifiedKFold, RandomizedSearchCV
from sklearn.metrics import confusion_matrix as cm, accuracy_score as ac, classification_report as report,\
roc_curve, roc_auc_score , recall_score , precision_score, f1_score

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
test_data=pd.read_csv("SalaryData_Test(1).csv")
test_data
# Out:
#        age      workclass      education  educationno        maritalstatus  \
# 0       25        Private           11th            7        Never-married
# 1       38        Private        HS-grad            9   Married-civ-spouse
# 2       28      Local-gov     Assoc-acdm           12   Married-civ-spouse
# 3       44        Private   Some-college           10   Married-civ-spouse
# 4       34        Private           10th            6        Never-married
# ...    ...            ...            ...          ...                  ...
# 15055   33        Private      Bachelors           13        Never-married
# 15056   39        Private      Bachelors           13             Divorced
# 15057   38        Private      Bachelors           13   Married-civ-spouse
# 15058   44        Private      Bachelors           13             Divorced
# 15059   35   Self-emp-inc      Bachelors           13   Married-civ-spouse
#
# ...

# %%
train_data=pd.read_csv("SalaryData_Train(1).csv.crdownload")
train_data
# Out:
#       age          workclass      education  educationno        maritalstatus  \
# 0      39          State-gov      Bachelors           13        Never-married
# 1      50   Self-emp-not-inc      Bachelors           13   Married-civ-spouse
# 2      38            Private        HS-grad            9             Divorced
# 3      53            Private           11th            7   Married-civ-spouse
# 4      28            Private      Bachelors           13   Married-civ-spouse
# ...   ...                ...            ...          ...                  ...
# 1814   45   Self-emp-not-inc        HS-grad            9   Married-civ-spouse
# 1815   35            Private   Some-college           10        Never-married
# 1816   26            Private        Masters           14        Never-married
# 1817   30            Private        HS-grad            9   Married-civ-spouse
# 1818   33            Private        HS-grad            9   Married-civ-spouse
#
# ...

# %%
from sklearn.preprocessing import LabelEncoder
encoder1=LabelEncoder()

# %%
train_data=train_data.apply(LabelEncoder().fit_transform)
train_data
# Out:
#       age  workclass  education  educationno  maritalstatus  occupation  \
# 0      22          5          9           12              4           0
# 1      33          4          9           12              2           3
# 2      21          2         11            8              0           5
# 3      36          2          1            6              2           5
# 4      11          2          9           12              2           9
# ...   ...        ...        ...          ...            ...         ...
# 1814   28          4         11            8              2          11
# 1815   18          2         15            9              4          11
# 1816    9          2         12           13              4           9
# 1817   13          2         11            8              2           7
# 1818   16          2         11            8              2          11
#
#       relationship  race  sex  capitalgain  capitalloss  hoursperweek  native  \
# ...

# %%
test_data=test_data.apply(LabelEncoder().fit_transform)
test_data
# Out:
#        age  workclass  education  educationno  maritalstatus  occupation  \
# 0        8          2          1            6              4           6
# 1       21          2         11            8              2           4
# 2       11          1          7           11              2          10
# 3       27          2         15            9              2           6
# 4       17          2          0            5              4           7
# ...    ...        ...        ...          ...            ...         ...
# 15055   16          2          9           12              4           9
# 15056   22          2          9           12              0           9
# 15057   21          2          9           12              2           9
# 15058   27          2          9           12              0           0
# 15059   18          3          9           12              2           3
#
#        relationship  race  sex  capitalgain  capitalloss  hoursperweek  \
# ...

# %%
train_data=train_data.drop(columns=['workclass','education','relationship','native','maritalstatus','sex','race'])
test_data=test_data.drop(columns=['workclass','education','relationship','native','maritalstatus','sex','race'])

# %%
train_data
# Out:
#       age  educationno  occupation  capitalgain  capitalloss  hoursperweek  \
# 0      22           12           0            8            0            32
# 1      33           12           3            0            0            10
# 2      21            8           5            0            0            32
# 3      36            6           5            0            0            32
# 4      11           12           9            0            0            32
# ...   ...          ...         ...          ...          ...           ...
# 1814   28            8          11            0            0            42
# 1815   18            9          11            0            0            32
# 1816    9           13           9           37            0            32
# 1817   13            8           7            0            0            46
# 1818   16            8          11           47           37            65
#
#       Salary
# 0          0
# 1          0
# 2          0
# ...

# %%
x_train=train_data.iloc[:,:-1]
y_train=train_data.iloc[:,-1]

# %%
x_train.shape,y_train.shape
# Out:
# ((1819, 6), (1819,))

# %%
test_data
# Out:
#        age  educationno  occupation  capitalgain  capitalloss  hoursperweek  \
# 0        8            6           6            0            0            39
# 1       21            8           4            0            0            49
# 2       11           11          10            0            0            39
# 3       27            9           6           87            0            39
# 4       17            5           7            0            0            29
# ...    ...          ...         ...          ...          ...           ...
# 15055   16           12           9            0            0            39
# 15056   22           12           9            0            0            35
# 15057   21           12           9            0            0            49
# 15058   27           12           0           73            0            39
# 15059   18           12           3            0            0            59
#
#        Salary
# 0           0
# 1           0
# ...

# %%
x_test=test_data.iloc[:,:-1]
y_test=test_data.iloc[:,-1]

# %%
x_test.shape,y_test.shape
# Out:
# ((15060, 6), (15060,))

# %%
model=SVC()
parameters=({'C':[1,15,14,13,12,11,10,0.1],
    'kernel':['rbf','polynomial'],'gamma':[50,5,10,0.5,1,0.001,0.0001,0.00001]})

# %%
grid=GridSearchCV(model,parameters,cv=10)

# %%
grid.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=10, estimator=SVC(),
#              param_grid={'C': [1, 15, 14, 13, 12, 11, 10, 0.1],
#                          'gamma': [50, 5, 10, 0.5, 1, 0.001, 0.0001, 1e-05],
#                          'kernel': ['rbf', 'polynomial']})

# %%
grid.best_score_
# Out:
# 0.8015451399429301

# %%
grid.best_params_
# Out:
# {'C': 11, 'gamma': 0.001, 'kernel': 'rbf'}

# %%
final_model=SVC( C=11,kernel='rbf', gamma=0.001)

# %%
final_model.fit(x_train,y_train)
# Out:
# SVC(C=11, gamma=0.001)

# %%
y_test_pred=final_model.predict(x_test)

# %%
print(classification_report(y_test,y_test_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.80      0.94      0.87     11360
#            1       0.62      0.28      0.38      3700
#
#     accuracy                           0.78     15060
#    macro avg       0.71      0.61      0.62     15060
# weighted avg       0.76      0.78      0.75     15060
